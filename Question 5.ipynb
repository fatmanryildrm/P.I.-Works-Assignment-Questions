# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("country_vaccination_stats.csv")

# %%
# All countrys median values
medyan = data.groupby("country").agg({"daily_vaccinations": "median"})

# %%
medyan
# Out:
#                       daily_vaccinations
# country
# Argentina                        11704.0
# Austria                           7953.0
# Bahrain                           3871.0
# Belgium                           3634.0
# Brazil                           27304.0
# Bulgaria                          1013.0
# Canada                           11577.5
# Chile                             1328.5
# China                           299107.5
# Costa Rica                         763.0
# Croatia                           2497.5
# Cyprus                             729.5
# Czechia                           5812.0
# Denmark                           7139.0
# Ecuador                            108.0
# England                         115637.0
# Estonia                           1051.5
# Finland                           2332.0
# France                           43961.0
# Germany                          52415.5
# Gibraltar                          744.0
# Greece                            5388.0
# ...

# %%
#And this is top-3 countries: the highest median daily vaccination numbers
medyan.nlargest(3,"daily_vaccinations")
# Out:
#                daily_vaccinations
# country
# United States            399093.0
# China                    299107.5
# India                    182551.5
